# %% [markdown]
# <img src="https://farm66.staticflickr.com/65535/49055715328_092031af74_o.png"  width="150" />
#
# ### CBPF - Centro Brasileiro de Pesquisas Físicas
#
# # Projeto final do curso de Análise de big data e Astroinformática
#
# ### João Paulo Correia de França
# ### contato: joao.contato505@gmail.com
#
#
# ### Professor: Clécio R. de Bom

# %%
import numpy as np
import pandas as pd
from glob import glob
import subprocess
from PIL import Image
import autolens.plot as aplt
import autofit as af
import autolens as al
#from ipywidgets import *

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# WARNING:autoconf.conf:Pushing new config with path /home/joao/.local/lib/python3.8/site-packages/autoarray/config
# 2021-11-10 17:17:58,498 - autoconf.conf - WARNING - Pushing new config with path /home/joao/.local/lib/python3.8/site-packages/autofit/config
# 2021-11-10 17:17:59,146 - autoconf.conf - WARNING - Pushing new config with path /home/joao/.local/lib/python3.8/site-packages/autogalaxy/config
# 2021-11-10 17:17:59,350 - autoconf.conf - WARNING - Pushing new config with path /home/joao/.local/lib/python3.8/site-packages/autolens/config

# %%
# pixel scale, which represents the conversion rate between pixel^2 and arcsec^2
pixel_scale = 0.263
print('1 pixel² is equivalent to arcsec² {:4.2f}'.format(pixel_scale))
# Out:
# 1 pixel² is equivalent to arcsec² 0.26

# %%
# Catalog simulation parameters (true values)
lenses_DESc = pd.read_csv('./lenses_DESc.txt',
                          sep=' ',
                          comment='#',
                          names=['id', 'zl', 'zs', 'b', 'sig_v', 'ql', 'rl', 'lens_g', 'lens_r', 'lens_i', 'xs', 'ys', 'qs', 'ps', 'rs', 'source_g', 'source_r', 'source_i', 'mu_s', 'g_band_coadd_seeing', 'g_band_coadd_signal_to_noise', 'r_band_coadd_seeing', 'r_band_coadd_signal_to_noise', 'i_band_coadd_seeing'])

# %%
lenses_DESc.head()
# Out:
#    id     zl     zs      b    sig_v     ql     rl  lens_g  lens_r  lens_i  \
# 0   0  0.320  1.784  1.497  265.112  0.771  1.330  19.961  18.086  17.442
# 1   1  0.402  1.790  1.372  264.665  0.811  0.819  20.778  18.833  18.103
# 2   3  0.569  1.285  1.361  318.578  0.671  0.853  21.374  19.530  18.255
# 3   4  0.189  3.385  1.686  257.082  0.709  2.291  18.166  16.757  16.249
# 4   5  0.568  1.057  0.658  242.661  0.768  0.409  22.679  20.836  19.562
#
#    ...       rs  source_g  source_r  source_i    mu_s  g_band_coadd_seeing  \
# 0  ...  131.188     0.290     6.413     1.352  37.000                1.352
# 1  ...   35.232     0.408     4.585     1.352  22.528                1.352
# 2  ...  113.910     0.290     8.931     1.352  32.892                1.352
# 3  ...  125.445     0.321     7.212     1.352  23.054                1.352
# 4  ...   53.932     0.008   156.589     1.352   0.002                1.352
#
#    g_band_coadd_signal_to_noise  r_band_coadd_seeing  \
# 0                        19.368                1.352
# 1                        11.003                1.352
# 2                        22.761                1.352
# 3                        15.983                1.352
# 4                        21.890                1.352
#
#    r_band_coadd_signal_to_noise  i_band_coadd_seeing
# 0                        11.432               32.021
# 1                         9.419               19.750
# 2                        16.575               28.284
# 3                         9.900               17.660
# 4                        25.334                0.000
#
# [5 rows x 24 columns]

# %%
image_data_paths=glob('./LensPop/images/*/')
print('Current strong lensing cutouts on path: {:4.0f}'.format(len(image_data_paths)))
# Out:
# Current strong lensing cutouts on path: 1404

# %%
# Redshift distribution of simulated strong lensing systems
 
plt.rcParams.update({"font.size": 13})

fig, ax = plt.subplots(1, 2, figsize=(10, 4))

ax[0].hist(lenses_DESc["zl"], density=True, ec="k", color="slateblue")
ax[0].set_xlabel("$z_l$")
ax[0].set_ylabel("f")

ax[1].hist(lenses_DESc["zs"], density=True, ec="k", color="slateblue")
ax[1].set_xlabel("$z_s$");

# %%
def call_STIFF(File_Path, File_Name, Bits = 16, Gamma_Type = 'REC.709', Gamma = 2.2, \
               Gamma_Fac = 1.0, Colour_Sat = 0., Negative = 'N', Verbose = 'QUIET', Copy_Header = 'N', \
               Write_XML = 'N', NThreads = 4):
    '''
    STIFF def function to build a RGB image from image bands
    
    File_Path: str
        path of the cutouts 
    File_Name: str
        output path of the rgb fits file
    Bits: float, defaut 16
        image bits
    Gamma_Type: str
        Gamma classification, defaut REC.709'
    Gamma: float
        Display gamma, default 2.2
    Gamma_Fac: float
        Luminance gamma correction factor, default 1.0
    Colour_Sat: float
        Colour saturation (0.0 = B&W), default 0.
    Negative: str
         Make negative of the image, default 'N'
    Verbose: str
        Report, default 'Quiet'
    Copy_Header: str
        Copy Header or not?, 'N'
    Write_XML: str
        Write a XML file or not?, default 'N'
    NThread: int
        Parallel processing threads, default 4
    '''
    
    general = f'-OUTFILE_NAME {File_Name} -BITS_PER_CHANNEL {Bits} '
    dynamic_range = f'-GAMMA_TYPE {Gamma_Type} -GAMMA {Gamma} -GAMMA_FAC {Gamma_Fac} -COLOUR_SAT {Colour_Sat} -NEGATIVE {Negative} '
    misc = f'-VERBOSE_TYPE {Verbose} -COPY_HEADER {Copy_Header} -WRITE_XML {Write_XML} -NTHREADS {NThreads} -COMPRESSION_QUALITY 100 -SATUR_LEVEL 100000'
    stiff_call = f'stiff {File_Path} '+general+dynamic_range+misc
    
    # run a subprocess call
    return subprocess.call(stiff_call, shell=True, stderr=subprocess.DEVNULL)

# %%
def get_image(image_id):
    '''
    Get image and build an RGB one based on stiff function
    
    image_id: int
        DES-c image id
    lens_sub: bool
        Read subtracted lens image (True) or the original one (False), default True
    '''

    # image in g-bandwidth
    image_g = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/galsub_g_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    # image in r-bandwidth
    image_r = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/galsub_r_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    # image in i-bandwidth
    image_i = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/galsub_i_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    # sigma image in g-bandwidth
    sigma_image_g = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/sigma_g_SDSS.fits",
                                         pixel_scales=pixel_scale,
                                         hdu=0)
    # sigma image in r-bandwidth
    sigma_image_r = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/sigma_r_SDSS.fits",
                                         pixel_scales=pixel_scale,
                                         hdu=0)
    # sigma image in i-bandwidth
    sigma_image_i = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/sigma_i_SDSS.fits",
                                         pixel_scales=pixel_scale,
                                         hdu=0)
    # psf image in g-bandwidth
    psf_g = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/psf_g_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    # psf image in r-bandwidth
    psf_r = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/psf_r_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    # psf image in i-bandwidth
    psf_i = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/psf_i_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    # building our data-lists
    image_al = [image_g, image_r, image_i]
    sigma_al = [sigma_image_g, sigma_image_r, sigma_image_i]
    psf_al = [psf_g, psf_r, psf_i]

    # generate a stiff (RGB) image
    call_STIFF(File_Path = "./LensPop/images/"+str(image_id)+"/galsub_i_SDSS.fits" + " " + \
               "./LensPop/images/"+str(image_id)+"/galsub_r_SDSS.fits" + " " + \
               "./LensPop/images/"+str(image_id)+"/galsub_g_SDSS.fits", File_Name = f"./stiff_systems/"+str(image_id)+".tif", Colour_Sat = 1.)
    # reading a tif image
    im = Image.open("./stiff_systems/"+str(image_id)+".tif")
    #tranforming into an array
    imarray = np.array(im)
    return image_al, sigma_al, psf_al, imarray

# %%
# pick up a random seed
np.random.seed(42)

# systems
systems = np.random.randint(low=0,
                            high=len(image_data_paths),
                            size=60)
print('systems: ', systems)

systems_cutouts = []
for i in range(0, len(systems)):
    image_al, sigma_al, psf_al, image_stiff = get_image(int(systems[i]))
    # buiding our cutouts
    systems_cutouts.append([image_al, sigma_al, psf_al, image_stiff])
# Out:
# systems:  [1126  860 1294 1130 1095 1044  121  466 1238  330   87 1396 1123  871
#   130 1332  769  343  805  385 1215  955  276 1184  459 1337   21  252
#   747  856  474 1082  510  699  975  189  957  686  957  562 1267  831
#  1154  646   20  840  166 1297  387  600  315   13  241  776 1369  564
#   897 1363   91 1390]

# %%
# ploting GRI and RGB images
fig, ax = plt.subplots(3, 4, figsize=(8, 8))

title = ["SDSSG", "SDSSR", "SDSSI", "RGB"]

for ii in range(0, len(ax)):
    image_al, sigma_al, psf_al, image_stiff = systems_cutouts[ii]
    for jj in range(0, len(ax[ii])):
        if jj < 3:
            ax[ii][jj].imshow(image_al[jj].reshape(76, 76), cmap="gist_gray")
            ax[ii][jj].set_xticks([])
            ax[ii][jj].set_yticks([])
            ax[ii][jj].set_title(title[jj])

        else:
            ax[ii][jj].imshow(image_stiff)
            ax[ii][jj].set_xticks([])
            ax[ii][jj].set_yticks([])
            ax[ii][jj].set_title(title[jj])

# %%
def prepare_image(cutout_data):
    '''
    def function to prepare our data into a PyAutoLens format (imaging object)
    cutout_data: list
        cutout data as [image, sigma image, point spread function, rgb image]
    '''
    
    for ii in range(0, len(cutout_data)):
        image_al, sigma_al, psf_al, image_stiff = systems_cutouts[ii]
        
        # mean image (mean of RGB)
        image = np.mean(image_al, axis=0).reshape(76,76)
        image = al.Array2D.manual(image, pixel_scales=pixel_scale)
        
        # same as image
        sigma = np.mean(sigma_al, axis=0).reshape(76,76)
        sigma = al.Array2D.manual(sigma, pixel_scales=pixel_scale)

        # psf as a Kernel2D, here we reshape into a odd Kernel
        psf = np.mean(psf_al, axis=0).reshape(76,76)
        psf = al.Kernel2D.manual(psf, pixel_scales=pixel_scale)
        trimmed_psf = al.preprocess.array_with_new_shape(array=psf, new_shape=(21, 21))
        
        # imaging object
        cutout_data[ii] = al.Imaging(image=image, psf=trimmed_psf, noise_map=sigma)

    return cutout_data

# %%
# main data array
data = prepare_image(systems_cutouts)

# %%
print("Applying a inverse modeling into our cutouts, please wait...")
for i in range(0, len(systems)):
    print("system: ", systems[i])
    # selecting data
    imaging = data[i]
    # apply a 2D circular mask envolving the strong lensing object it may fail, please verify if its consistent
    mask = al.Mask2D.circular(shape_native=imaging.shape_native,
                              pixel_scales=imaging.pixel_scales,
                              radius=7.)
    imaging = imaging.apply_mask(mask=mask)
    
    # if systems in the lenses DESc:
    if systems[i] in list(lenses_DESc["id"]):
        
        
        # lens and source redshift
        zl, zs = float(lenses_DESc[lenses_DESc["id"]==systems[i]]["zl"]), float(lenses_DESc[lenses_DESc["id"]==systems[i]]["zs"])
        print('Lens redshift and source refshift are, respectively, ', zl, zs)

        print('Building our model')
        # lens galaxy + bulge
        bulge = af.Model(al.lp.EllDevVaucouleurs)
        lens = af.Model(al.Galaxy,
                        redshift=zl,
                        bulge=bulge,
                        mass=al.mp.EllIsothermal)
        # source galaxy
        source = af.Model(al.Galaxy,
                          redshift=zs,
                          disk=al.lp.EllExponential)
        # building our model
        model = af.Collection(galaxies=af.Collection(lens=lens, source=source))

        # Search object
        print('Starting to fit...')
        search = af.DynestyStatic(path_prefix="./",
                                  unique_tag=str(systems[i]),
                                  nlive=50,
                                  number_of_cores=3) # be carefull with this!

        analysis = al.AnalysisImaging(dataset=imaging)

        result = search.fit(model=model, analysis=analysis)
print("Done")
# Out:
# Applying a inverse modeling into our cutouts, please wait...
# system:  1126
# Lens redshift and source refshift are, respectively,  0.521 2.821
# Building our model
# Starting to fit...
# 2021-11-10 17:18:14,750 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:14,751 - root - INFO - Starting search
# 2021-11-10 17:18:15,375 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:15,398 - root - INFO - Removing zip file
# system:  860
# Lens redshift and source refshift are, respectively,  0.525 0.914
# Building our model
# Starting to fit...
# 2021-11-10 17:18:15,902 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:15,902 - root - INFO - Starting search
# 2021-11-10 17:18:16,488 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:16,504 - root - INFO - Removing zip file
# system:  1294
# Lens redshift and source refshift are, respectively,  0.351 1.288
# Building our model
# Starting to fit...
# 2021-11-10 17:18:16,954 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:16,955 - root - INFO - Starting search
# 2021-11-10 17:18:17,538 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:17,559 - root - INFO - Removing zip file
# system:  1130
# Lens redshift and source refshift are, respectively,  0.346 2.574
# Building our model
# Starting to fit...
# 2021-11-10 17:18:18,136 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:18,137 - root - INFO - Starting search
# 2021-11-10 17:18:18,742 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:18,766 - root - INFO - Removing zip file
# system:  1095
# Lens redshift and source refshift are, respectively,  0.282 1.114
# Building our model
# Starting to fit...
# 2021-11-10 17:18:19,234 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:19,234 - root - INFO - Starting search
# 2021-11-10 17:18:19,680 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:19,696 - root - INFO - Removing zip file
# system:  1044
# system:  121
# Lens redshift and source refshift are, respectively,  0.377 1.82
# Building our model
# Starting to fit...
# 2021-11-10 17:18:20,097 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:20,098 - root - INFO - Starting search
# 2021-11-10 17:18:20,580 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:20,596 - root - INFO - Removing zip file
# system:  466
# Lens redshift and source refshift are, respectively,  0.948 2.398
# Building our model
# Starting to fit...
# 2021-11-10 17:18:21,097 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:21,098 - root - INFO - Starting search
# 2021-11-10 17:18:22,378 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:22,433 - root - INFO - Removing zip file
# system:  1238
# Lens redshift and source refshift are, respectively,  0.248 2.104
# Building our model
# Starting to fit...
# 2021-11-10 17:18:23,284 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:23,285 - root - INFO - Starting search
# 2021-11-10 17:18:23,810 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:23,830 - root - INFO - Removing zip file
# system:  330
# Lens redshift and source refshift are, respectively,  0.288 0.812
# Building our model
# Starting to fit...
# 2021-11-10 17:18:24,282 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:24,283 - root - INFO - Starting search
# 2021-11-10 17:18:24,965 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:24,987 - root - INFO - Removing zip file
# system:  87
# Lens redshift and source refshift are, respectively,  0.432 1.637
# Building our model
# Starting to fit...
# 2021-11-10 17:18:25,561 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:25,562 - root - INFO - Starting search
# 2021-11-10 17:18:25,998 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:26,008 - root - INFO - Removing zip file
# system:  1396
# system:  1123
# system:  871
# Lens redshift and source refshift are, respectively,  0.285 1.062
# Building our model
# Starting to fit...
# 2021-11-10 17:18:26,409 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:26,410 - root - INFO - Starting search
# 2021-11-10 17:18:26,930 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:27,067 - root - INFO - Removing zip file
# system:  130
# Lens redshift and source refshift are, respectively,  0.39 2.015
# Building our model
# Starting to fit...
# 2021-11-10 17:18:27,560 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:27,561 - root - INFO - Starting search
# 2021-11-10 17:18:28,333 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:28,363 - root - INFO - Removing zip file
# system:  1332
# system:  769
# Lens redshift and source refshift are, respectively,  0.288 1.618
# Building our model
# Starting to fit...
# 2021-11-10 17:18:29,044 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:29,045 - root - INFO - Starting search
# 2021-11-10 17:18:29,715 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:29,735 - root - INFO - Removing zip file
# system:  343
# Lens redshift and source refshift are, respectively,  0.396 1.993
# Building our model
# Starting to fit...
# 2021-11-10 17:18:30,259 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:30,260 - root - INFO - Starting search
# 2021-11-10 17:18:30,963 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:31,005 - root - INFO - Removing zip file
# system:  805
# Lens redshift and source refshift are, respectively,  0.119 0.659
# Building our model
# Starting to fit...
# 2021-11-10 17:18:31,633 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:31,634 - root - INFO - Starting search
# 2021-11-10 17:18:32,148 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:32,165 - root - INFO - Removing zip file
# system:  385
# Lens redshift and source refshift are, respectively,  0.427 3.045
# Building our model
# Starting to fit...
# 2021-11-10 17:18:32,685 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:32,686 - root - INFO - Starting search
# 2021-11-10 17:18:33,221 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:33,237 - root - INFO - Removing zip file
# system:  1215
# Lens redshift and source refshift are, respectively,  0.557 2.812
# Building our model
# Starting to fit...
# 2021-11-10 17:18:33,768 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:33,769 - root - INFO - Starting search
# 2021-11-10 17:18:34,828 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:34,974 - root - INFO - Removing zip file
# system:  955
# Lens redshift and source refshift are, respectively,  0.46 1.551
# Building our model
# Starting to fit...
# 2021-11-10 17:18:35,865 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:35,867 - root - INFO - Starting search
# 2021-11-10 17:18:36,366 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:36,394 - root - INFO - Removing zip file
# system:  276
# Lens redshift and source refshift are, respectively,  0.457 1.717
# Building our model
# Starting to fit...
# 2021-11-10 17:18:36,799 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:36,801 - root - INFO - Starting search
# 2021-11-10 17:18:37,296 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:37,323 - root - INFO - Removing zip file
# system:  1184
# Lens redshift and source refshift are, respectively,  0.26 0.931
# Building our model
# Starting to fit...
# 2021-11-10 17:18:37,712 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:37,714 - root - INFO - Starting search
# 2021-11-10 17:18:38,348 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:38,374 - root - INFO - Removing zip file
# system:  459
# Lens redshift and source refshift are, respectively,  0.692 2.127
# Building our model
# Starting to fit...
# 2021-11-10 17:18:39,044 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:39,045 - root - INFO - Starting search
# 2021-11-10 17:18:39,580 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:39,616 - root - INFO - Removing zip file
# system:  1337
# Lens redshift and source refshift are, respectively,  0.307 1.054
# Building our model
# Starting to fit...
# 2021-11-10 17:18:40,051 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:40,053 - root - INFO - Starting search
# 2021-11-10 17:18:42,241 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:42,257 - root - INFO - Removing zip file
# system:  21
# Lens redshift and source refshift are, respectively,  0.373 1.92
# Building our model
# Starting to fit...
# 2021-11-10 17:18:42,715 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:42,716 - root - INFO - Starting search
# 2021-11-10 17:18:43,287 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:43,306 - root - INFO - Removing zip file
# system:  252
# Lens redshift and source refshift are, respectively,  0.139 0.614
# Building our model
# Starting to fit...
# 2021-11-10 17:18:43,777 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:43,778 - root - INFO - Starting search
# 2021-11-10 17:18:44,548 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:44,681 - root - INFO - Removing zip file
# system:  747
# Lens redshift and source refshift are, respectively,  1.168 2.596
# Building our model
# Starting to fit...
# 2021-11-10 17:18:45,295 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:45,296 - root - INFO - Starting search
# 2021-11-10 17:18:45,298 - root - INFO - Already completed, skipping non-linear search.
# 2021-11-10 17:18:45,442 - root - INFO - Removing zip file
# system:  856
# Lens redshift and source refshift are, respectively,  0.78 2.49
# Building our model
# Starting to fit...
# 2021-11-10 17:18:46,232 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:18:46,233 - root - INFO - Starting search
# 2021-11-10 17:18:46,241 - root - INFO - Saving path info
# 2021-11-10 17:18:46,290 - root - INFO - Not complete. Starting non-linear search.
# 2021-11-10 17:18:46,291 - root - INFO - number_of_cores == 3...
# 2021-11-10 17:18:46,292 - root - WARNING - ...using SneakyPool. This copies the likelihood functionto each process on instantiation to avoid copying multipletimes.
# 2021-11-10 17:18:46,293 - process 0 - INFO - created
# 2021-11-10 17:18:46,295 - process 1 - INFO - created
# 2021-11-10 17:18:46,296 - process 2 - INFO - created
# 2021-11-10 17:18:46,333 - autofit.non_linear.initializer - INFO - Generating initial samples of model, which are subject to prior limits and other constraints.
# 2021-11-10 17:18:47,277 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# /home/joao/.local/lib/python3.8/site-packages/dynesty/dynesty.py:373: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 158it [00:22,  2.48it/s, bound: 0 | nc: 26 | ncall: 1591 | eff(%):  9.931 | loglstar:   -inf < -7899.619 <    inf | logz: -7907.353 +/-  0.544 | dlogz: 1372.833 >  0.059]   /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 177it [00:23, 14.65it/s, bound: 3 | nc: 5 | ncall: 1689 | eff(%): 10.480 | loglstar:   -inf < -7562.852 <    inf | logz: -7570.961 +/-  0.558 | dlogz: 1008.158 >  0.059] /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 725it [00:51, 14.17it/s, +50 | bound: 87 | nc: 1 | ncall: 5052 | eff(%): 15.340 | loglstar:   -inf < -5776.968 <    inf | logz: -5795.950 +/-  1.212 | dlogz:  1.099 >  0.059]
# 2021-11-10 17:19:38,627 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1437it [00:47, 30.34it/s, +50 | bound: 205 | nc: 1 | ncall: 10055 | eff(%): 14.789 | loglstar:   -inf < -5669.342 <    inf | logz: -5699.738 +/-  1.208 | dlogz:  0.128 >  0.059]
# 2021-11-10 17:20:38,349 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2032it [00:49, 41.17it/s, +50 | bound: 314 | nc: 1 | ncall: 15059 | eff(%): 13.826 | loglstar:   -inf < -5380.378 <    inf | logz: -5425.236 +/-  1.513 | dlogz:  1.094 >  0.059]
# 2021-11-10 17:21:40,739 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2717it [00:47, 57.57it/s, +50 | bound: 435 | nc: 1 | ncall: 20064 | eff(%): 13.791 | loglstar:   -inf < -5197.915 <    inf | logz: -5256.210 +/-  2.394 | dlogz:  1.011 >  0.059]
# 2021-11-10 17:22:41,480 - root - INFO - 20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3412it [01:06, 51.17it/s, +50 | bound: 552 | nc: 1 | ncall: 25159 | eff(%): 13.760 | loglstar:   -inf < -5182.639 <    inf | logz: -5249.842 +/-  1.623 | dlogz:  0.014 >  0.059]
# 2021-11-10 17:24:05,248 - root - INFO - 25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3714it [00:27, 135.43it/s, +50 | bound: 600 | nc: 1 | ncall: 27160 | eff(%): 13.859 | loglstar:   -inf < -5179.025 <    inf | logz: -5249.733 +/-  1.581 | dlogz:  0.001 >  0.059]
# 2021-11-10 17:24:50,983 - root - INFO - 30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3714it [00:00, 1846348.83it/s, +50 | bound: 600 | nc: 1 | ncall: 27160 | eff(%): 13.859 | loglstar:   -inf < -5179.025 <    inf | logz: -5249.733 +/-  1.581 | dlogz:  0.001 >  0.059]
# 2021-11-10 17:25:12,466 - root - INFO - 35000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-11-10 17:25:25,889 - root - INFO - 40000 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/joao/.local/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 2021-11-10 17:26:17,251 - root - INFO - Removing zip file
# system:  474
# Lens redshift and source refshift are, respectively,  0.262 1.609
# Building our model
# Starting to fit...
# 2021-11-10 17:26:18,838 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:26:18,841 - root - INFO - Starting search
# 2021-11-10 17:26:18,845 - root - INFO - Saving path info
# 2021-11-10 17:26:18,991 - root - INFO - Not complete. Starting non-linear search.
# 2021-11-10 17:26:18,994 - root - INFO - number_of_cores == 3...
# 2021-11-10 17:26:18,995 - root - WARNING - ...using SneakyPool. This copies the likelihood functionto each process on instantiation to avoid copying multipletimes.
# 2021-11-10 17:26:18,998 - process 0 - INFO - created
# 2021-11-10 17:26:19,000 - process 1 - INFO - created
# 2021-11-10 17:26:19,002 - process 2 - INFO - created
# 2021-11-10 17:26:19,088 - autofit.non_linear.initializer - INFO - Generating initial samples of model, which are subject to prior limits and other constraints.
# 2021-11-10 17:26:20,699 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# /home/joao/.local/lib/python3.8/site-packages/dynesty/dynesty.py:373: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 170it [00:32,  1.52it/s, bound: 0 | nc: 51 | ncall: 1740 | eff(%):  9.770 | loglstar:   -inf < -5462.182 <    inf | logz: -5467.473 +/-  0.411 | dlogz: 56.604 >  0.059]     /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 329it [00:49, 18.36it/s, bound: 28 | nc: 5 | ncall: 3087 | eff(%): 10.658 | loglstar:   -inf < -5423.104 <    inf | logz: -5431.765 +/-  0.565 | dlogz: 28.205 >  0.059] /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 400it [00:59, 10.00it/s, bound: 43 | nc: 5 | ncall: 4250 | eff(%):  9.412 | loglstar:   -inf < -5409.082 <    inf | logz: -5418.999 +/-  0.593 | dlogz: 16.710 >  0.059]/home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 423it [01:09,  6.09it/s, +50 | bound: 50 | nc: 1 | ncall: 5243 | eff(%):  9.022 | loglstar:   -inf < -5394.397 <    inf | logz: -5405.377 +/-  0.663 | dlogz:  0.235 >  0.059]
# 2021-11-10 17:27:30,339 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 460it [00:20, 16.62it/s, bound: 64 | nc: 5 | ncall: 7223 | eff(%):  6.369 | loglstar:   -inf < -5401.751 <    inf | logz: -5412.522 +/-  0.614 | dlogz: 21.865 >  0.059]   /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 602it [00:51, 11.59it/s, +50 | bound: 106 | nc: 1 | ncall: 10246 | eff(%):  6.363 | loglstar:   -inf < -5324.795 <    inf | logz: -5341.342 +/-  1.369 | dlogz:  1.099 >  0.059]
# 2021-11-10 17:28:35,457 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 763it [01:21,  9.39it/s, +50 | bound: 170 | nc: 1 | ncall: 15280 | eff(%):  5.321 | loglstar:   -inf < -5303.221 <    inf | logz: -5322.860 +/-  1.088 | dlogz:  1.036 >  0.059]
# 2021-11-10 17:30:11,788 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1443it [00:43, 33.50it/s, +50 | bound: 284 | nc: 1 | ncall: 20282 | eff(%):  7.361 | loglstar:   -inf < -5267.157 <    inf | logz: -5299.682 +/-  1.495 | dlogz:  0.702 >  0.059]
# 2021-11-10 17:31:18,596 - root - INFO - 20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2240it [00:44, 50.86it/s, +50 | bound: 403 | nc: 1 | ncall: 25283 | eff(%):  9.057 | loglstar:   -inf < -5249.192 <    inf | logz: -5293.221 +/-  1.310 | dlogz:  0.014 >  0.059]
# 2021-11-10 17:32:15,160 - root - INFO - 25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2446it [00:19, 126.06it/s, +50 | bound: 438 | nc: 1 | ncall: 26773 | eff(%):  9.323 | loglstar:   -inf < -5247.570 <    inf | logz: -5293.173 +/-  1.262 | dlogz:  0.001 >  0.059]
# 2021-11-10 17:32:53,777 - root - INFO - 30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2446it [00:00, 579488.68it/s, +50 | bound: 438 | nc: 1 | ncall: 26773 | eff(%):  9.323 | loglstar:   -inf < -5247.570 <    inf | logz: -5293.173 +/-  1.262 | dlogz:  0.001 >  0.059]
# 2021-11-10 17:33:22,242 - root - INFO - 35000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-11-10 17:33:49,444 - root - INFO - 40000 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/joao/.local/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 2021-11-10 17:34:40,395 - root - INFO - Removing zip file
# system:  1082
# Lens redshift and source refshift are, respectively,  0.322 1.382
# Building our model
# Starting to fit...
# 2021-11-10 17:34:40,971 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:34:40,973 - root - INFO - Starting search
# 2021-11-10 17:34:40,975 - root - INFO - Saving path info
# 2021-11-10 17:34:41,024 - root - INFO - Not complete. Starting non-linear search.
# 2021-11-10 17:34:41,025 - root - INFO - number_of_cores == 3...
# 2021-11-10 17:34:41,026 - root - WARNING - ...using SneakyPool. This copies the likelihood functionto each process on instantiation to avoid copying multipletimes.
# 2021-11-10 17:34:41,027 - process 0 - INFO - created
# 2021-11-10 17:34:41,028 - process 1 - INFO - created
# 2021-11-10 17:34:41,029 - process 2 - INFO - created
# 2021-11-10 17:34:41,112 - autofit.non_linear.initializer - INFO - Generating initial samples of model, which are subject to prior limits and other constraints.
# 2021-11-10 17:34:41,837 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# /home/joao/.local/lib/python3.8/site-packages/dynesty/dynesty.py:373: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 153it [00:22,  1.97it/s, bound: 1 | nc: 6 | ncall: 1576 | eff(%):  9.708 | loglstar:   -inf < -5349.558 <    inf | logz: -5355.151 +/-  0.394 | dlogz: 39.285 >  0.059]    /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 254it [00:31, 11.67it/s, bound: 20 | nc: 5 | ncall: 2439 | eff(%): 10.414 | loglstar:   -inf < -5324.081 <    inf | logz: -5330.776 +/-  0.467 | dlogz: 20.958 >  0.059] /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 614it [00:55, 11.03it/s, +50 | bound: 79 | nc: 1 | ncall: 5052 | eff(%): 13.143 | loglstar:   -inf < -5284.032 <    inf | logz: -5300.813 +/-  2.256 | dlogz:  1.097 >  0.059]
# 2021-11-10 17:35:37,685 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 746it [00:20, 28.03it/s, bound: 104 | nc: 5 | ncall: 6224 | eff(%): 11.986 | loglstar:   -inf < -5293.040 <    inf | logz: -5308.084 +/-  0.710 | dlogz: 14.144 >  0.059]  /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 932it [01:21,  4.36it/s, bound: 141 | nc: 5 | ncall: 9508 | eff(%):  9.802 | loglstar:   -inf < -5284.213 <    inf | logz: -5302.823 +/-  0.815 | dlogz:  5.203 >  0.059] /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 946it [01:31, 10.35it/s, +50 | bound: 146 | nc: 1 | ncall: 10073 | eff(%):  9.888 | loglstar:   -inf < -5278.780 <    inf | logz: -5299.587 +/-  1.085 | dlogz:  0.145 >  0.059]
# 2021-11-10 17:37:23,441 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1065it [00:33, 43.68it/s, bound: 183 | nc: 171 | ncall: 12984 | eff(%):  8.202 | loglstar:   -inf < -5279.224 <    inf | logz: -5300.308 +/-  0.858 | dlogz:  7.925 >  0.059]/home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1094it [00:53, 20.39it/s, +50 | bound: 195 | nc: 1 | ncall: 15103 | eff(%):  7.575 | loglstar:   -inf < -5265.639 <    inf | logz: -5291.468 +/-  1.677 | dlogz:  0.817 >  0.059]
# 2021-11-10 17:38:33,372 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1156it [01:10, 16.45it/s, +50 | bound: 230 | nc: 1 | ncall: 20140 | eff(%):  5.988 | loglstar:   -inf < -5257.996 <    inf | logz: -5285.508 +/-  2.163 | dlogz:  1.095 >  0.059]
# 2021-11-10 17:39:57,705 - root - INFO - 20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1200it [00:40, 29.64it/s, +50 | bound: 257 | nc: 1 | ncall: 25269 | eff(%):  4.947 | loglstar:   -inf < -5255.436 <    inf | logz: -5283.467 +/-  1.441 | dlogz:  0.875 >  0.059]
# 2021-11-10 17:41:00,670 - root - INFO - 25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1258it [00:40, 30.95it/s, +50 | bound: 292 | nc: 1 | ncall: 30302 | eff(%):  4.317 | loglstar:   -inf < -5250.160 <    inf | logz: -5278.428 +/-  1.072 | dlogz:  0.446 >  0.059]
# 2021-11-10 17:41:53,092 - root - INFO - 30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1374it [01:37, 14.09it/s, +50 | bound: 343 | nc: 1 | ncall: 35313 | eff(%):  4.033 | loglstar:   -inf < -5240.315 <    inf | logz: -5271.434 +/-  1.430 | dlogz:  0.682 >  0.059]
# 2021-11-10 17:43:45,329 - root - INFO - 35000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1454it [00:40, 35.93it/s, +50 | bound: 378 | nc: 1 | ncall: 40450 | eff(%):  3.718 | loglstar:   -inf < -5238.176 <    inf | logz: -5270.476 +/-  1.407 | dlogz:  0.503 >  0.059]
# 2021-11-10 17:44:38,977 - root - INFO - 40000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1530it [01:14, 20.45it/s, +50 | bound: 425 | nc: 1 | ncall: 45465 | eff(%):  3.475 | loglstar:   -inf < -5234.818 <    inf | logz: -5268.297 +/-  1.515 | dlogz:  0.387 >  0.059]
# 2021-11-10 17:46:09,732 - root - INFO - 45000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1572it [00:37, 41.71it/s, +50 | bound: 459 | nc: 1 | ncall: 50520 | eff(%):  3.211 | loglstar:   -inf < -5234.818 <    inf | logz: -5268.357 +/-  1.303 | dlogz:  0.197 >  0.059]
# 2021-11-10 17:47:04,327 - root - INFO - 50000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1612it [01:26, 18.59it/s, +50 | bound: 490 | nc: 1 | ncall: 55615 | eff(%):  2.988 | loglstar:   -inf < -5234.818 <    inf | logz: -5268.413 +/-  1.211 | dlogz:  0.099 >  0.059]
# 2021-11-10 17:48:46,762 - root - INFO - 55000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1646it [00:35, 46.16it/s, +50 | bound: 514 | nc: 1 | ncall: 60626 | eff(%):  2.797 | loglstar:   -inf < -5234.499 <    inf | logz: -5268.453 +/-  1.192 | dlogz:  0.074 >  0.059]
# 2021-11-10 17:49:35,416 - root - INFO - 60000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1727it [01:00, 28.41it/s, bound: 545 | nc: 17 | ncall: 64440 | eff(%):  2.680 | loglstar:   -inf < -5235.376 <    inf | logz: -5268.864 +/-  1.119 | dlogz:  2.142 >  0.059]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 2021-11-10 17:50:57,643 - root - INFO - 65000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 2021-11-10 17:51:21,191 - root - INFO - 70000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-11-10 17:51:35,509 - root - INFO - 75000 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/joao/.local/lib/python3.8/site-packages/dynesty/plotting.py:173: UserWarning: The number of iterations and samples differ by an amount that isn't the number of final live points. `mark_final_live` has been disabled.
#   warnings.warn("The number of iterations and samples differ "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 2021-11-10 17:52:28,669 - root - INFO - Removing zip file
# system:  510
# Lens redshift and source refshift are, respectively,  0.106 0.521
# Building our model
# Starting to fit...
# 2021-11-10 17:52:29,496 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:52:29,498 - root - INFO - Starting search
# 2021-11-10 17:52:29,500 - root - INFO - Saving path info
# 2021-11-10 17:52:29,549 - root - INFO - Not complete. Starting non-linear search.
# 2021-11-10 17:52:29,550 - root - INFO - number_of_cores == 3...
# 2021-11-10 17:52:29,551 - root - WARNING - ...using SneakyPool. This copies the likelihood functionto each process on instantiation to avoid copying multipletimes.
# 2021-11-10 17:52:29,552 - process 0 - INFO - created
# 2021-11-10 17:52:29,553 - process 1 - INFO - created
# 2021-11-10 17:52:29,555 - process 2 - INFO - created
# 2021-11-10 17:52:29,687 - autofit.non_linear.initializer - INFO - Generating initial samples of model, which are subject to prior limits and other constraints.
# 2021-11-10 17:52:30,415 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# /home/joao/.local/lib/python3.8/site-packages/dynesty/dynesty.py:373: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 170it [00:43,  1.04s/it, bound: 0 | nc: 73 | ncall: 1739 | eff(%):  9.776 | loglstar:   -inf < -6235.116 <    inf | logz: -6241.689 +/-  0.464 | dlogz: 105.873 >  0.059]    /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 391it [01:15,  5.16it/s, +50 | bound: 61 | nc: 1 | ncall: 5210 | eff(%):  8.464 | loglstar:   -inf < -6099.642 <    inf | logz: -6111.599 +/-  0.478 | dlogz:  0.844 >  0.059]
# 2021-11-10 17:53:46,413 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1010it [00:50, 19.84it/s, +50 | bound: 170 | nc: 1 | ncall: 10213 | eff(%): 10.379 | loglstar:   -inf < -6020.262 <    inf | logz: -6044.806 +/-  1.860 | dlogz:  1.044 >  0.059]
# 2021-11-10 17:54:48,320 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1726it [00:49, 34.76it/s, +50 | bound: 285 | nc: 1 | ncall: 15226 | eff(%): 11.664 | loglstar:   -inf < -5999.933 <    inf | logz: -6032.146 +/-  1.076 | dlogz:  0.003 >  0.059]
# 2021-11-10 17:55:50,080 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1778it [00:03, 501.99it/s, +50 | bound: 293 | nc: 1 | ncall: 15542 | eff(%): 11.762 | loglstar:   -inf < -5999.772 <    inf | logz: -6032.141 +/-  1.070 | dlogz:  0.001 >  0.059]
# 2021-11-10 17:56:08,237 - root - INFO - 20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1778it [00:00, 747241.73it/s, +50 | bound: 293 | nc: 1 | ncall: 15542 | eff(%): 11.762 | loglstar:   -inf < -5999.772 <    inf | logz: -6032.141 +/-  1.070 | dlogz:  0.001 >  0.059]
# 2021-11-10 17:56:23,798 - root - INFO - 25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-11-10 17:56:37,919 - root - INFO - 30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/joao/.local/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 2021-11-10 17:57:34,965 - root - INFO - Removing zip file
# system:  699
# system:  975
# Lens redshift and source refshift are, respectively,  0.502 1.599
# Building our model
# Starting to fit...
# 2021-11-10 17:57:36,214 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-11-10 17:57:36,217 - root - INFO - Starting search
# 2021-11-10 17:57:36,221 - root - INFO - Saving path info
# 2021-11-10 17:57:36,323 - root - INFO - Not complete. Starting non-linear search.
# 2021-11-10 17:57:36,325 - root - INFO - number_of_cores == 3...
# 2021-11-10 17:57:36,327 - root - WARNING - ...using SneakyPool. This copies the likelihood functionto each process on instantiation to avoid copying multipletimes.
# 2021-11-10 17:57:36,330 - process 0 - INFO - created
# 2021-11-10 17:57:36,333 - process 1 - INFO - created
# 2021-11-10 17:57:36,337 - process 2 - INFO - created
# 2021-11-10 17:57:36,565 - autofit.non_linear.initializer - INFO - Generating initial samples of model, which are subject to prior limits and other constraints.
# 2021-11-10 17:57:38,068 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# /home/joao/.local/lib/python3.8/site-packages/dynesty/dynesty.py:373: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 154it [00:24,  1.30it/s, bound: 0 | nc: 36 | ncall: 1546 | eff(%):  9.961 | loglstar:   -inf < -6093.387 <    inf | logz: -6099.933 +/-  0.528 | dlogz: 342.796 >  0.059]    /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 439it [00:55,  7.93it/s, +50 | bound: 64 | nc: 1 | ncall: 5052 | eff(%):  9.679 | loglstar:   -inf < -5552.374 <    inf | logz: -5565.692 +/-  0.961 | dlogz:  1.099 >  0.059]
# 2021-11-10 17:58:33,540 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 442it [00:01, 333.32it/s, bound: 65 | nc: 5 | ncall: 5073 | eff(%):  8.713 | loglstar:   -inf < -5699.112 <    inf | logz: -5711.093 +/-  0.694 | dlogz: 150.509 >  0.059]/home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 498it [00:18, 16.19it/s, bound: 89 | nc: 114 | ncall: 7185 | eff(%):  6.931 | loglstar:   -inf < -5665.408 <    inf | logz: -5678.332 +/-  0.716 | dlogz: 132.194 >  0.059]/home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 558it [00:44, 12.54it/s, +50 | bound: 122 | nc: 1 | ncall: 10111 | eff(%):  6.013 | loglstar:   -inf < -5536.695 <    inf | logz: -5552.370 +/-  1.115 | dlogz:  1.098 >  0.059]
# 2021-11-10 17:59:29,075 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 0it [00:00, ?it/s]/home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 633it [01:07,  9.39it/s, +50 | bound: 151 | nc: 1 | ncall: 15294 | eff(%):  4.466 | loglstar:   -inf < -5535.774 <    inf | logz: -5551.741 +/-    nan | dlogz:  0.474 >  0.059]
# 2021-11-10 18:00:50,028 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 720it [01:03, 11.34it/s, +50 | bound: 174 | nc: 1 | ncall: 20515 | eff(%):  3.753 | loglstar:   -inf < -5510.490 <    inf | logz: -5529.372 +/-  1.314 | dlogz:  1.098 >  0.059]
# 2021-11-10 18:02:07,727 - root - INFO - 20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 891it [01:09, 12.86it/s, +50 | bound: 208 | nc: 1 | ncall: 25547 | eff(%):  3.683 | loglstar:   -inf < -5438.163 <    inf | logz: -5460.432 +/-  1.319 | dlogz:  1.099 >  0.059]
# 2021-11-10 18:03:30,668 - root - INFO - 25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 966it [02:16,  7.08it/s, +50 | bound: 220 | nc: 1 | ncall: 36538 | eff(%):  2.781 | loglstar:   -inf < -5417.506 <    inf | logz: -5441.260 +/-  1.326 | dlogz:  1.099 >  0.059]
# 2021-11-10 18:06:02,695 - root - INFO - 30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1824it [00:55, 33.08it/s, +50 | bound: 341 | nc: 1 | ncall: 41541 | eff(%):  4.511 | loglstar:   -inf < -5203.566 <    inf | logz: -5244.236 +/-  1.776 | dlogz:  1.049 >  0.059]
# 2021-11-10 18:07:28,668 - root - INFO - 35000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2640it [00:58, 45.23it/s, +50 | bound: 461 | nc: 1 | ncall: 46547 | eff(%):  5.779 | loglstar:   -inf < -5165.671 <    inf | logz: -5219.515 +/-  1.633 | dlogz:  0.090 >  0.059]
# 2021-11-10 18:08:40,166 - root - INFO - 40000 Iterations: Performing update (Visualization, outputting samples, etc.).
