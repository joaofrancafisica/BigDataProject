# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
import autolens as al
import subprocess
from PIL import Image

# %matplotlib inline

# %%
image_data_paths=glob("./LensPop/images/*/")
print("Current strong lensing cutouts on path: ", len(image_data_paths))
# Out:
# Current strong lensing cutouts on path:  1404

# %%
results=pd.read_csv("./results_catalog.txt", sep=",")
results.head()
# Out:
#    id  Einstein_Radius_actual  Einstein_radius_Inception  \
# 0   0                   1.716                    1.54308
# 1   1                   1.433                    1.78372
# 2   3                   1.325                    1.34623
# 3   4                   0.993                    1.17223
# 4   5                   1.072                    1.28036
#
#    Einstein_Radius_Sequential  Einstein_Radius_ResNet  \
# 0                     1.63556                 1.60419
# 1                     1.58602                 1.58634
# 2                     1.53789                 1.03845
# 3                     1.11795                 1.07006
# 4                     1.18530                 1.22772
#
#    Einstein_Radius_ResNetXt  Sigma_V_actual  Sigma_V_Inception  \
# 0                   1.87451         279.904            291.215
# 1                   1.48138         346.114            332.267
# 2                   1.41403         260.482            257.948
# 3                   1.29498         269.369            258.188
# 4                   1.06243         224.926            255.804
#
#    Sigma_V_Sequential  Sigma_V_ResNet  ...  RedShift_Lens_ZL_actual  \
# 0             292.208         293.536  ...                    0.378
# 1             340.017         335.997  ...                    0.834
# 2             260.697         245.173  ...                    0.381
# 3             248.708         242.475  ...                    0.258
# 4             233.241         245.332  ...                    0.350
#
#    RedShift_Lens_ZL_Inception  RedShift_Lens_ZL_Sequential  \
# 0                    0.398122                     0.435342
# 1                    0.805235                     0.794858
# 2                    0.324546                     0.370329
# 3                    0.242271                     0.217607
# 4                    0.379734                     0.380019
#
#    RedShift_Lens_ZL_ResNet  RedShift_Lens_ZL_ResNetXt  \
# 0                 0.377477                   0.419813
# 1                 0.718788                   0.767183
# 2                 0.317963                   0.353732
# 3                 0.248105                   0.235744
# 4                 0.427648                   0.407995
#
#    Redshift_Source_ZS_actual  Redshift_Source_ZS_Inception  \
# 0                      2.776                      2.564690
# 1                      1.827                      2.324070
# 2                      1.633                      1.537820
# 3                      0.527                      0.660075
# 4                      2.007                      1.102130
#
#    Redshift_Source_ZS_Sequential  Redshift_Source_ZS_ResNet  \
# 0                        2.03192                    2.24000
# 1                        2.40681                    2.29777
# 2                        1.92407                    2.36051
# 3                        1.29210                    1.00098
# 4                        1.57857                    1.56287
#
#    Redshift_Source_ZS_ResNetXt
# 0                     1.929650
# 1                     2.656040
# 2                     1.725220
# 3                     0.764566
# 4                     1.636210
#
# [5 rows x 21 columns]

# %%
plt.rcParams.update({"font.size": 13})

fig, ax = plt.subplots(1, 2, figsize=(10, 4))

ax[0].hist(results["RedShift_Lens_ZL_actual"], density=True, ec="k", color="slateblue")
ax[0].set_xlabel("$z_l$")
ax[0].set_ylabel("f")

ax[1].hist(results["Redshift_Source_ZS_actual"], density=True, ec="k", color="slateblue")
ax[1].set_xlabel("$z_s$");

# %%
def call_STIFF(File_Path,  # If single name, just the file. If RGB image, image_red image_green image_blue
               File_Name, 
               Bits = 16,                # 8, 16, -32
               Gamma_Type = 'REC.709',   # 'SRGB' or 'POWER-LAW'
               Gamma = 2.2,              # Display gamma
               Gamma_Fac = 1.0,          # Luminance gamma correction factor
               Colour_Sat = 1.0,         # Colour saturation (0.0 = B&W)
               Negative = 'N',           # Make negative of the image
               Verbose = 'QUIET',        # 'QUIET', 'NORMAL' or 'FULL'
               Copy_Header = 'N',        # Copy FITS header to description field?
               Write_XML = 'N',          # Write XML file (Y/N)?
               NThreads = 4):            # Parallel processing
    general = f'-OUTFILE_NAME {File_Name} -BITS_PER_CHANNEL {Bits} '
    dynamic_range = f'-GAMMA_TYPE {Gamma_Type} -GAMMA {Gamma} -GAMMA_FAC {Gamma_Fac} -COLOUR_SAT {Colour_Sat} -NEGATIVE {Negative} '
    misc = f'-VERBOSE_TYPE {Verbose} -COPY_HEADER {Copy_Header} -WRITE_XML {Write_XML} -NTHREADS {NThreads} -COMPRESSION_QUALITY 100 -SATUR_LEVEL 100000'
    stiff_call = f'stiff {File_Path} '+general+dynamic_range+misc
    return subprocess.call(stiff_call, shell=True, \
                stderr=subprocess.DEVNULL) # Hide outputs from STIFF

# %%
def get_image(image_id):
    
    image_g = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/galsub_g_SDSS.fits",
                                   pixel_scales=0.263,
                                   hdu=0)
    image_r = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/galsub_r_SDSS.fits",
                                   pixel_scales=0.263,
                                   hdu=0)
    image_i = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/galsub_i_SDSS.fits",
                                   pixel_scales=0.263,
                                   hdu=0)
    
    sigma_image_g = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/sigma_g_SDSS.fits",
                                         pixel_scales=0.263,
                                         hdu=0)
    sigma_image_r = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/sigma_r_SDSS.fits",
                                         pixel_scales=0.263,
                                         hdu=0)
    sigma_image_i = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/sigma_i_SDSS.fits",
                                         pixel_scales=0.263,
                                         hdu=0)
    
    psf_g = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/psf_g_SDSS.fits",
                                   pixel_scales=0.263,
                                   hdu=0)
    psf_r = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/psf_r_SDSS.fits",
                                   pixel_scales=0.263,
                                   hdu=0)
    psf_i = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/psf_i_SDSS.fits",
                                   pixel_scales=0.263,
                                   hdu=0)
    image_al = [image_g, image_r, image_i]
    sigma_al = [sigma_image_g, sigma_image_r, sigma_image_i]
    psf_al = [psf_g, psf_r, psf_i]
    
    # generate a stiff (RGB) image
    
    call_STIFF(File_Path = "./LensPop/images/"+str(image_id)+"/galsub_i_SDSS.fits" + " " + \
           "./LensPop/images/"+str(image_id)+"/galsub_r_SDSS.fits" + " " + \
           "./LensPop/images/"+str(image_id)+"/galsub_g_SDSS.fits", File_Name = f"./stiff_systems/"+str(image_id)+".tif")
    
    im = Image.open("./stiff_systems/"+str(image_id)+".tif")
    
    imarray = np.array(im)

    return image_al, sigma_al, psf_al, np.array(im)

# %%
np.random.seed(42)

systems = np.random.randint(low=0, high=len(image_data_paths), size=3)

# %%
fig, ax = plt.subplots(len(systems), 4, figsize=(8, 8))

title = ["G", "R", "I", "RGB"]

for ii in range(0, len(ax)):
    image, sigma_al, image_al, image_stiff = get_image(int(systems[ii]))
    for jj in range(0, len(ax[ii])):
        if jj < 3:
            ax[ii][jj].imshow(image[jj].reshape(76, 76))
            ax[ii][jj].set_xticks([])
            ax[ii][jj].set_yticks([])
            ax[ii][jj].set_title(title[jj])

        else:
            ax[ii][jj].imshow(image_stiff)
            ax[ii][jj].set_xticks([])
            ax[ii][jj].set_yticks([])
            ax[ii][jj].set_title(title[jj])
