# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
import autolens as al
import subprocess
from PIL import Image
import autolens.plot as aplt
import autofit as af

# %matplotlib inline
# Out:
# WARNING:autoconf.conf:Pushing new config with path /home/joao/.local/lib/python3.8/site-packages/autoarray/config
# 2021-10-31 19:45:38,457 - autoconf.conf - WARNING - Pushing new config with path /home/joao/.local/lib/python3.8/site-packages/autofit/config
# 2021-10-31 19:45:38,554 - autoconf.conf - WARNING - Pushing new config with path /home/joao/.local/lib/python3.8/site-packages/autogalaxy/config
# 2021-10-31 19:45:38,651 - autoconf.conf - WARNING - Pushing new config with path /home/joao/.local/lib/python3.8/site-packages/autolens/config

# %%
pixel_scale = 0.263

# %%
image_data_paths=glob("./LensPop/images/*/")
print("Current strong lensing cutouts on path: ", len(image_data_paths))
# Out:
# Current strong lensing cutouts on path:  1404

# %%
results=pd.read_csv("./results_catalog.txt", sep=",")
results.head()
# Out:
#    id  Einstein_Radius_actual  Einstein_radius_Inception  \
# 0   0                   1.716                    1.54308
# 1   1                   1.433                    1.78372
# 2   3                   1.325                    1.34623
# 3   4                   0.993                    1.17223
# 4   5                   1.072                    1.28036
#
#    Einstein_Radius_Sequential  Einstein_Radius_ResNet  \
# 0                     1.63556                 1.60419
# 1                     1.58602                 1.58634
# 2                     1.53789                 1.03845
# 3                     1.11795                 1.07006
# 4                     1.18530                 1.22772
#
#    Einstein_Radius_ResNetXt  Sigma_V_actual  Sigma_V_Inception  \
# 0                   1.87451         279.904            291.215
# 1                   1.48138         346.114            332.267
# 2                   1.41403         260.482            257.948
# 3                   1.29498         269.369            258.188
# 4                   1.06243         224.926            255.804
#
#    Sigma_V_Sequential  Sigma_V_ResNet  ...  RedShift_Lens_ZL_actual  \
# 0             292.208         293.536  ...                    0.378
# 1             340.017         335.997  ...                    0.834
# 2             260.697         245.173  ...                    0.381
# 3             248.708         242.475  ...                    0.258
# 4             233.241         245.332  ...                    0.350
#
#    RedShift_Lens_ZL_Inception  RedShift_Lens_ZL_Sequential  \
# 0                    0.398122                     0.435342
# 1                    0.805235                     0.794858
# 2                    0.324546                     0.370329
# 3                    0.242271                     0.217607
# 4                    0.379734                     0.380019
#
#    RedShift_Lens_ZL_ResNet  RedShift_Lens_ZL_ResNetXt  \
# 0                 0.377477                   0.419813
# 1                 0.718788                   0.767183
# 2                 0.317963                   0.353732
# 3                 0.248105                   0.235744
# 4                 0.427648                   0.407995
#
#    Redshift_Source_ZS_actual  Redshift_Source_ZS_Inception  \
# 0                      2.776                      2.564690
# 1                      1.827                      2.324070
# 2                      1.633                      1.537820
# 3                      0.527                      0.660075
# 4                      2.007                      1.102130
#
#    Redshift_Source_ZS_Sequential  Redshift_Source_ZS_ResNet  \
# 0                        2.03192                    2.24000
# 1                        2.40681                    2.29777
# 2                        1.92407                    2.36051
# 3                        1.29210                    1.00098
# 4                        1.57857                    1.56287
#
#    Redshift_Source_ZS_ResNetXt
# 0                     1.929650
# 1                     2.656040
# 2                     1.725220
# 3                     0.764566
# 4                     1.636210
#
# [5 rows x 21 columns]

# %%
plt.rcParams.update({"font.size": 13})

fig, ax = plt.subplots(1, 2, figsize=(10, 4))

ax[0].hist(results["RedShift_Lens_ZL_actual"], density=True, ec="k", color="slateblue")
ax[0].set_xlabel("$z_l$")
ax[0].set_ylabel("f")

ax[1].hist(results["Redshift_Source_ZS_actual"], density=True, ec="k", color="slateblue")
ax[1].set_xlabel("$z_s$");

# %%
def call_STIFF(File_Path,  # If single name, just the file. If RGB image, image_red image_green image_blue
               File_Name, 
               Bits = 16,                # 8, 16, -32
               Gamma_Type = 'REC.709',   # 'SRGB' or 'POWER-LAW'
               Gamma = 2.2,              # Display gamma
               Gamma_Fac = 1.0,          # Luminance gamma correction factor
               Colour_Sat = 0.,         # Colour saturation (0.0 = B&W)
               Negative = 'N',           # Make negative of the image
               Verbose = 'QUIET',        # 'QUIET', 'NORMAL' or 'FULL'
               Copy_Header = 'N',        # Copy FITS header to description field?
               Write_XML = 'N',          # Write XML file (Y/N)?
               NThreads = 4):            # Parallel processing
    general = f'-OUTFILE_NAME {File_Name} -BITS_PER_CHANNEL {Bits} '
    dynamic_range = f'-GAMMA_TYPE {Gamma_Type} -GAMMA {Gamma} -GAMMA_FAC {Gamma_Fac} -COLOUR_SAT {Colour_Sat} -NEGATIVE {Negative} '
    misc = f'-VERBOSE_TYPE {Verbose} -COPY_HEADER {Copy_Header} -WRITE_XML {Write_XML} -NTHREADS {NThreads} -COMPRESSION_QUALITY 100 -SATUR_LEVEL 100000'
    stiff_call = f'stiff {File_Path} '+general+dynamic_range+misc
    return subprocess.call(stiff_call, shell=True, \
                stderr=subprocess.DEVNULL) # Hide outputs from STIFF

# %%
def get_image(image_id):
    
    image_g = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/galsub_g_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    image_r = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/galsub_r_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    image_i = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/galsub_i_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    
    sigma_image_g = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/sigma_g_SDSS.fits",
                                         pixel_scales=pixel_scale,
                                         hdu=0)
    sigma_image_r = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/sigma_r_SDSS.fits",
                                         pixel_scales=pixel_scale,
                                         hdu=0)
    sigma_image_i = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/sigma_i_SDSS.fits",
                                         pixel_scales=pixel_scale,
                                         hdu=0)
    
    psf_g = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/psf_g_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    psf_r = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/psf_r_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    psf_i = al.Array2D.from_fits("./LensPop/images/"+str(image_id)+"/psf_i_SDSS.fits",
                                   pixel_scales=pixel_scale,
                                   hdu=0)
    image_al = [image_g, image_r, image_i]
    sigma_al = [sigma_image_g, sigma_image_r, sigma_image_i]
    psf_al = [psf_g, psf_r, psf_i]
    
    # generate a stiff (RGB) image
    
    call_STIFF(File_Path = "./LensPop/images/"+str(image_id)+"/galsub_i_SDSS.fits" + " " + \
           "./LensPop/images/"+str(image_id)+"/galsub_r_SDSS.fits" + " " + \
           "./LensPop/images/"+str(image_id)+"/galsub_g_SDSS.fits", File_Name = f"./stiff_systems/"+str(image_id)+".tif", Colour_Sat = 1.)
    
    im = Image.open("./stiff_systems/"+str(image_id)+".tif")
    
    imarray = np.array(im)

    return image_al, sigma_al, psf_al, np.array(im)

# %%
np.random.seed(42)

systems = np.random.randint(low=0, high=len(image_data_paths), size=3)

systems_cutouts = []
for i in range(0, len(systems)):
    image_al, sigma_al, psf_al, image_stiff = get_image(int(systems[i]))
    systems_cutouts.append([image_al, sigma_al, psf_al, image_stiff])

# %%
fig, ax = plt.subplots(len(systems), 4, figsize=(8, 8))

title = ["SDSSG", "SDSSR", "SDSSI", "RGB"]

for ii in range(0, len(ax)):
    image_al, sigma_al, psf_al, image_stiff = systems_cutouts[ii]
    for jj in range(0, len(ax[ii])):
        if jj < 3:
            ax[ii][jj].imshow(image_al[jj].reshape(76, 76), cmap="gist_gray")
            ax[ii][jj].set_xticks([])
            ax[ii][jj].set_yticks([])
            ax[ii][jj].set_title(title[jj])

        else:
            ax[ii][jj].imshow(image_stiff)
            ax[ii][jj].set_xticks([])
            ax[ii][jj].set_yticks([])
            ax[ii][jj].set_title(title[jj])

# %%
def prepare_image(cutout_data):
    
    for ii in range(0, len(cutout_data)):
        image_al, sigma_al, psf_al, image_stiff = systems_cutouts[ii]
        
        image = np.mean(image_al, axis=0).reshape(76,76)
        image = al.Array2D.manual(image, pixel_scales=pixel_scale)
        
        sigma = np.mean(sigma_al, axis=0).reshape(76,76)
        sigma = al.Array2D.manual(sigma, pixel_scales=pixel_scale)

        psf = np.mean(psf_al, axis=0).reshape(76,76)
        psf = al.Kernel2D.manual(psf, pixel_scales=pixel_scale)
        
        trimmed_psf = al.preprocess.array_with_new_shape(array=psf, new_shape=(21, 21))

        #new_psf = psf.rescaled_with_odd_dimensions_from_rescale_factor(rescale_factor=1)
        
        cutout_data[ii] = al.Imaging(image=image, psf=trimmed_psf, noise_map=sigma)

    return cutout_data

# %%
data = prepare_image(systems_cutouts)

# %%
visuals_2d = aplt.Visuals2D()
array_plotter = aplt.Array2DPlotter(array=data[0].psf, visuals_2d=visuals_2d)
array_plotter.figure_2d()

# %%
imaging = data[0]

# %%
mask = al.Mask2D.circular(shape_native=imaging.shape_native,
                          pixel_scales=imaging.pixel_scales,
                          radius=9.9)
imaging = imaging.apply_mask(mask=mask)
# Out:
# The image and noise map of the `Imaging` objected had been padded to the dimensions(4460,). This is because the blurring region around its mask, which defines wherePSF flux may be convolved into the masked region, extended beyond the edge of the image.This can be prevented by using a smaller mask, smaller PSF kernel size or manually paddingthe image and noise-map yourself.

# %%
visuals_2d = aplt.Visuals2D()
array_plotter = aplt.Array2DPlotter(array=imaging.psf, visuals_2d=visuals_2d)
array_plotter.figure_2d()

# %%
#zl, zs = float(results[results["id"]==systems[0]]["RedShift_Lens_ZL_actual"]), float(results[results["id"]==systems[0]]["Redshift_Source_ZS_actual"])

# %%
zl = 0.521
zs = 2.821

# %%
bulge = af.Model(al.lp.EllDevVaucouleurs)
lens = af.Model(al.Galaxy,
                redshift=zl,
                bulge=bulge,
                mass=al.mp.EllIsothermal)

source = af.Model(al.Galaxy,
                  redshift=zs,
                  disk=al.lp.EllExponential)

model = af.Collection(galaxies=af.Collection(lens=lens, source=source))

# %%
search = af.DynestyStatic(
    path_prefix="./",
    unique_tag=str(systems[0]),
    nlive=50,
    number_of_cores=3
)
analysis = al.AnalysisImaging(dataset=imaging)

result = search.fit(model=model, analysis=analysis)
# Out:
# 2021-10-31 19:45:43,788 - autofit.non_linear.abstract_search - INFO - Creating search
# 2021-10-31 19:45:43,789 - root - INFO - Starting search
# 2021-10-31 19:45:43,792 - root - INFO - Saving path info
# 2021-10-31 19:45:43,845 - root - INFO - Not complete. Starting non-linear search.
# 2021-10-31 19:45:43,846 - root - INFO - number_of_cores == 3...
# 2021-10-31 19:45:43,847 - root - WARNING - ...using SneakyPool. This copies the likelihood functionto each process on instantiation to avoid copying multipletimes.
# 2021-10-31 19:45:43,848 - process 0 - INFO - created
# 2021-10-31 19:45:43,849 - process 1 - INFO - created
# 2021-10-31 19:45:43,850 - process 2 - INFO - created
# 2021-10-31 19:45:43,870 - autofit.non_linear.initializer - INFO - Generating initial samples of model, which are subject to prior limits and other constraints.
# 2021-10-31 19:45:44,780 - root - INFO - No Dynesty samples found, beginning new non-linear search.
# /home/joao/.local/lib/python3.8/site-packages/dynesty/dynesty.py:373: UserWarning: A note of caution: having `nlive < ndim * (ndim + 1) // 2` may result in unconstrained bounding distributions.
#   warnings.warn("A note of caution: "
# 157it [00:22,  1.11s/it, bound: 0 | nc: 144 | ncall: 1580 | eff(%):  9.937 | loglstar:   -inf < -10685.557 <    inf | logz: -10691.421 +/-  0.454 | dlogz: 37.883 >  0.059]  /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 622it [00:54, 11.41it/s, +50 | bound: 82 | nc: 1 | ncall: 5055 | eff(%): 13.294 | loglstar:   -inf < -10635.063 <    inf | logz: -10650.750 +/-  2.212 | dlogz:  0.451 >  0.059]
# 2021-10-31 19:46:39,441 - root - INFO - 5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 624it [00:00, 3349.47it/s, bound: 83 | nc: 9 | ncall: 5099 | eff(%): 12.238 | loglstar:   -inf < -10642.081 <    inf | logz: -10652.387 +/-  0.572 | dlogz:  4.996 >  0.059]/home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1031it [00:50, 20.23it/s, +50 | bound: 168 | nc: 1 | ncall: 10056 | eff(%): 10.750 | loglstar:   -inf < -10594.880 <    inf | logz: -10619.012 +/-  1.243 | dlogz:  0.591 >  0.059]
# 2021-10-31 19:47:50,120 - root - INFO - 10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1033it [00:00, 5603.03it/s, bound: 168 | nc: 5 | ncall: 10080 | eff(%): 10.248 | loglstar:   -inf < -10609.051 <    inf | logz: -10631.146 +/-  0.909 | dlogz: 15.933 >  0.059]/home/joao/.local/lib/python3.8/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 1642it [00:54, 29.94it/s, +50 | bound: 271 | nc: 1 | ncall: 15066 | eff(%): 11.231 | loglstar:   -inf < -10578.388 <    inf | logz: -10613.506 +/-  1.525 | dlogz:  0.235 >  0.059]
# 2021-10-31 19:49:04,964 - root - INFO - 15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1938it [00:23, 80.76it/s, +50 | bound: 326 | nc: 1 | ncall: 17423 | eff(%): 11.410 | loglstar:   -inf < -10577.912 <    inf | logz: -10613.448 +/-  1.112 | dlogz:  0.001 >  0.059]
# 2021-10-31 19:49:50,348 - root - INFO - 20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1938it [00:00, 967340.37it/s, +50 | bound: 326 | nc: 1 | ncall: 17423 | eff(%): 11.410 | loglstar:   -inf < -10577.912 <    inf | logz: -10613.448 +/-  1.112 | dlogz:  0.001 >  0.059]
# 2021-10-31 19:50:13,933 - root - INFO - 25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2021-10-31 19:50:34,856 - root - INFO - 30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# /home/joao/.local/lib/python3.8/site-packages/dynesty/plotting.py:245: UserWarning: Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
#   axes[i].set_ylim([ymin, ymax])
# 2021-10-31 19:51:33,491 - root - INFO - Removing zip file

# %%
fit_imaging_plotter = aplt.FitImagingPlotter(fit=result.max_log_likelihood_fit)
fit_imaging_plotter.subplot_fit_imaging()

# %%
results[results["id"]==systems[0]]
# Out:
#        id  Einstein_Radius_actual  Einstein_radius_Inception  \
# 984  1126                   0.931                   0.808638
#
#      Einstein_Radius_Sequential  Einstein_Radius_ResNet  \
# 984                     0.79745                0.933774
#
#      Einstein_Radius_ResNetXt  Sigma_V_actual  Sigma_V_Inception  \
# 984                  0.792441         339.868            222.695
#
#      Sigma_V_Sequential  Sigma_V_ResNet  ...  RedShift_Lens_ZL_actual  \
# 984             233.447         255.362  ...                    1.005
#
#      RedShift_Lens_ZL_Inception  RedShift_Lens_ZL_Sequential  \
# 984                    0.668272                      0.67238
#
#      RedShift_Lens_ZL_ResNet  RedShift_Lens_ZL_ResNetXt  \
# 984                 0.859536                   0.729872
#
#      Redshift_Source_ZS_actual  Redshift_Source_ZS_Inception  \
# 984                      1.634                       2.23685
#
#      Redshift_Source_ZS_Sequential  Redshift_Source_ZS_ResNet  \
# 984                        1.63683                    2.30666
#
#      Redshift_Source_ZS_ResNetXt
# 984                      1.84914
#
# [1 rows x 21 columns]
